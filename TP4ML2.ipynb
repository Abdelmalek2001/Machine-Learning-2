# %% [markdown]
# <p style="color: yellow; font-size: 30px;">
#  Exercice 1 : Initialisation de l’Environnement 🚖
# </p>

# %%
import gymnasium as gym
import numpy as np

env = gym.make("Taxi-v3")

state_size = env.observation_space.n
action_size = env.action_space.n

policy_table = np.ones((state_size, action_size)) / action_size
value_table = np.zeros(state_size)

print("Premières lignes de policy_table:")
print(policy_table[:5])

print("\nPremières valeurs de value_table:")
print(value_table[:5])
# Out:
# Premières lignes de policy_table:
# [[0.16666667 0.16666667 0.16666667 0.16666667 0.16666667 0.16666667]
#  [0.16666667 0.16666667 0.16666667 0.16666667 0.16666667 0.16666667]
#  [0.16666667 0.16666667 0.16666667 0.16666667 0.16666667 0.16666667]
#  [0.16666667 0.16666667 0.16666667 0.16666667 0.16666667 0.16666667]
#  [0.16666667 0.16666667 0.16666667 0.16666667 0.16666667 0.16666667]]
#
# Premières valeurs de value_table:
# [0. 0. 0. 0. 0.]

# %% [markdown]
# <p style="color: yellow; font-size: 30px;">
#  Exercice 2 : Collecte d’épisodes 📂
# </p>

# %%
import gymnasium as gym

env = gym.make("Taxi-v3")

for episode in range(20):
    state, _ = env.reset()
    done = False
    step = 0
    print(f"\nÉpisode {episode + 1}:")

    while not done:
        action = env.action_space.sample()  # Action aléatoire
        next_state, reward, done, _, _ = env.step(action)
        print(f"Étape {step}: Action = {action}, Récompense = {reward}")
        step += 1
# Out:
# Épisode 1:
# Étape 0: Action = 3, Récompense = -1
# Étape 1: Action = 4, Récompense = -10
# Étape 2: Action = 2, Récompense = -1
# Étape 3: Action = 2, Récompense = -1
# Étape 4: Action = 0, Récompense = -1
# Étape 5: Action = 0, Récompense = -1
# Étape 6: Action = 0, Récompense = -1
# Étape 7: Action = 3, Récompense = -1
# Étape 8: Action = 0, Récompense = -1
# Étape 9: Action = 2, Récompense = -1
# Étape 10: Action = 0, Récompense = -1
# Étape 11: Action = 3, Récompense = -1
# Étape 12: Action = 3, Récompense = -1
# Étape 13: Action = 5, Récompense = -10
# Étape 14: Action = 0, Récompense = -1
# Étape 15: Action = 5, Récompense = -10
# Étape 16: Action = 0, Récompense = -1
# Étape 17: Action = 1, Récompense = -1
# Étape 18: Action = 1, Récompense = -1
# Étape 19: Action = 3, Récompense = -1
# Étape 20: Action = 4, Récompense = -10
# Étape 21: Action = 3, Récompense = -1
# Étape 22: Action = 0, Récompense = -1
# Étape 23: Action = 2, Récompense = -1
# Étape 24: Action = 0, Récompense = -1
# Étape 25: Action = 0, Récompense = -1
# Étape 26: Action = 2, Récompense = -1
# Étape 27: Action = 5, Récompense = -10
# Étape 28: Action = 2, Récompense = -1
# Étape 29: Action = 0, Récompense = -1
# Étape 30: Action = 0, Récompense = -1
# Étape 31: Action = 0, Récompense = -1
# Étape 32: Action = 5, Récompense = -10
# Étape 33: Action = 3, Récompense = -1
# Étape 34: Action = 0, Récompense = -1
# Étape 35: Action = 3, Récompense = -1
# Étape 36: Action = 0, Récompense = -1
# Étape 37: Action = 4, Récompense = -10
# Étape 38: Action = 0, Récompense = -1
# Étape 39: Action = 2, Récompense = -1
# Étape 40: Action = 4, Récompense = -10
# Étape 41: Action = 0, Récompense = -1
# Étape 42: Action = 4, Récompense = -10
# Étape 43: Action = 5, Récompense = -10
# Étape 44: Action = 2, Récompense = -1
# Étape 45: Action = 4, Récompense = -10
# Étape 46: Action = 0, Récompense = -1
# Étape 47: Action = 1, Récompense = -1
# Étape 48: Action = 2, Récompense = -1
# Étape 49: Action = 1, Récompense = -1
# Étape 50: Action = 2, Récompense = -1
# Étape 51: Action = 5, Récompense = -10
# Étape 52: Action = 4, Récompense = -10
# Étape 53: Action = 4, Récompense = -10
# Étape 54: Action = 3, Récompense = -1
# Étape 55: Action = 5, Récompense = -10
# Étape 56: Action = 2, Récompense = -1
# Étape 57: Action = 0, Récompense = -1
# Étape 58: Action = 1, Récompense = -1
# Étape 59: Action = 4, Récompense = -10
# Étape 60: Action = 0, Récompense = -1
# Étape 61: Action = 1, Récompense = -1
# Étape 62: Action = 2, Récompense = -1
# Étape 63: Action = 5, Récompense = -10
# Étape 64: Action = 1, Récompense = -1
# Étape 65: Action = 5, Récompense = -10
# Étape 66: Action = 5, Récompense = -10
# Étape 67: Action = 1, Récompense = -1
# Étape 68: Action = 5, Récompense = -10
# Étape 69: Action = 1, Récompense = -1
# Étape 70: Action = 0, Récompense = -1
# Étape 71: Action = 4, Récompense = -10
# Étape 72: Action = 1, Récompense = -1
# Étape 73: Action = 0, Récompense = -1
# Étape 74: Action = 1, Récompense = -1
# Étape 75: Action = 5, Récompense = -10
# Étape 76: Action = 3, Récompense = -1
# Étape 77: Action = 0, Récompense = -1
# Étape 78: Action = 3, Récompense = -1
# Étape 79: Action = 3, Récompense = -1
# Étape 80: Action = 1, Récompense = -1
# Étape 81: Action = 3, Récompense = -1
# Étape 82: Action = 3, Récompense = -1
# Étape 83: Action = 5, Récompense = -10
# Étape 84: Action = 0, Récompense = -1
# Étape 85: Action = 4, Récompense = -10
# Étape 86: Action = 0, Récompense = -1
# Étape 87: Action = 2, Récompense = -1
# Étape 88: Action = 4, Récompense = -10
# Étape 89: Action = 2, Récompense = -1
# Étape 90: Action = 4, Récompense = -10
# Étape 91: Action = 0, Récompense = -1
# Étape 92: Action = 1, Récompense = -1
# Étape 93: Action = 0, Récompense = -1
# Étape 94: Action = 1, Récompense = -1
# Étape 95: Action = 4, Récompense = -10
# Étape 96: Action = 3, Récompense = -1
# Étape 97: Action = 2, Récompense = -1
# Étape 98: Action = 5, Récompense = -10
# Étape 99: Action = 5, Récompense = -10
# Étape 100: Action = 4, Récompense = -10
# Étape 101: Action = 1, Récompense = -1
# Étape 102: Action = 4, Récompense = -10
# Étape 103: Action = 0, Récompense = -1
# Étape 104: Action = 3, Récompense = -1
# Étape 105: Action = 5, Récompense = -10
# Étape 106: Action = 4, Récompense = -10
# Étape 107: Action = 4, Récompense = -10
# Étape 108: Action = 5, Récompense = -10
# Étape 109: Action = 4, Récompense = -10
# Étape 110: Action = 2, Récompense = -1
# Étape 111: Action = 0, Récompense = -1
# Étape 112: Action = 2, Récompense = -1
# Étape 113: Action = 1, Récompense = -1
# Étape 114: Action = 2, Récompense = -1
# Étape 115: Action = 1, Récompense = -1
# Étape 116: Action = 0, Récompense = -1
# Étape 117: Action = 1, Récompense = -1
# Étape 118: Action = 4, Récompense = -10
# Étape 119: Action = 1, Récompense = -1
# Étape 120: Action = 5, Récompense = -10
# Étape 121: Action = 0, Récompense = -1
# Étape 122: Action = 3, Récompense = -1
# Étape 123: Action = 0, Récompense = -1
# Étape 124: Action = 0, Récompense = -1
# Étape 125: Action = 3, Récompense = -1
# Étape 126: Action = 2, Récompense = -1
# Étape 127: Action = 5, Récompense = -10
# Étape 128: Action = 4, Récompense = -10
# Étape 129: Action = 4, Récompense = -10
# Étape 130: Action = 5, Récompense = -10
# Étape 131: Action = 5, Récompense = -10
# Étape 132: Action = 5, Récompense = -10
# Étape 133: Action = 4, Récompense = -10
# Étape 134: Action = 1, Récompense = -1
# Étape 135: Action = 3, Récompense = -1
# Étape 136: Action = 4, Récompense = -10
# Étape 137: Action = 3, Récompense = -1
# Étape 138: Action = 0, Récompense = -1
# Étape 139: Action = 1, Récompense = -1
# Étape 140: Action = 3, Récompense = -1
# Étape 141: Action = 5, Récompense = -10
# Étape 142: Action = 0, Récompense = -1
# Étape 143: Action = 4, Récompense = -10
# Étape 144: Action = 5, Récompense = -10
# Étape 145: Action = 4, Récompense = -10
# Étape 146: Action = 1, Récompense = -1
# Étape 147: Action = 3, Récompense = -1
# Étape 148: Action = 2, Récompense = -1
# Étape 149: Action = 1, Récompense = -1
# Étape 150: Action = 2, Récompense = -1
# Étape 151: Action = 0, Récompense = -1
# Étape 152: Action = 5, Récompense = -10
# Étape 153: Action = 2, Récompense = -1
# Étape 154: Action = 4, Récompense = -10
# Étape 155: Action = 5, Récompense = -10
# Étape 156: Action = 1, Récompense = -1
# Étape 157: Action = 4, Récompense = -10
# Étape 158: Action = 5, Récompense = -10
# Étape 159: Action = 4, Récompense = -10
# Étape 160: Action = 3, Récompense = -1
# Étape 161: Action = 0, Récompense = -1
# Étape 162: Action = 1, Récompense = -1
# Étape 163: Action = 2, Récompense = -1
# Étape 164: Action = 2, Récompense = -1
# Étape 165: Action = 4, Récompense = -10
# Étape 166: Action = 2, Récompense = -1
# Étape 167: Action = 3, Récompense = -1
# Étape 168: Action = 2, Récompense = -1
# Étape 169: Action = 4, Récompense = -10
# Étape 170: Action = 4, Récompense = -10
# Étape 171: Action = 0, Récompense = -1
# Étape 172: Action = 4, Récompense = -10
# Étape 173: Action = 4, Récompense = -10
# Étape 174: Action = 2, Récompense = -1
# Étape 175: Action = 1, Récompense = -1
# Étape 176: Action = 3, Récompense = -1
# Étape 177: Action = 2, Récompense = -1
# Étape 178: Action = 4, Récompense = -10
# Étape 179: Action = 5, Récompense = -10
# Étape 180: Action = 2, Récompense = -1
# Étape 181: Action = 3, Récompense = -1
# Étape 182: Action = 4, Récompense = -10
# Étape 183: Action = 5, Récompense = -10
# Étape 184: Action = 3, Récompense = -1
# Étape 185: Action = 4, Récompense = -10
# Étape 186: Action = 5, Récompense = -10
# Étape 187: Action = 1, Récompense = -1
# Étape 188: Action = 0, Récompense = -1
# Étape 189: Action = 2, Récompense = -1
# Étape 190: Action = 5, Récompense = -10
# Étape 191: Action = 3, Récompense = -1
# Étape 192: Action = 1, Récompense = -1
# Étape 193: Action = 2, Récompense = -1
# Étape 194: Action = 5, Récompense = -10
# Étape 195: Action = 4, Récompense = -10
# Étape 196: Action = 2, Récompense = -1
# Étape 197: Action = 1, Récompense = -1
# Étape 198: Action = 2, Récompense = -1
# Étape 199: Action = 0, Récompense = -1
# Étape 200: Action = 2, Récompense = -1
# Étape 201: Action = 0, Récompense = -1
# Étape 202: Action = 3, Récompense = -1
# Étape 203: Action = 0, Récompense = -1
# Étape 204: Action = 2, Récompense = -1
# Étape 205: Action = 5, Récompense = -10
# Étape 206: Action = 2, Récompense = -1
# Étape 207: Action = 0, Récompense = -1
# Étape 208: Action = 4, Récompense = -10
# Étape 209: Action = 5, Récompense = -10
# Étape 210: Action = 4, Récompense = -10
# Étape 211: Action = 3, Récompense = -1
# Étape 212: Action = 1, Récompense = -1
# Étape 213: Action = 3, Récompense = -1
# Étape 214: Action = 3, Récompense = -1
# Étape 215: Action = 4, Récompense = -10
# Étape 216: Action = 3, Récompense = -1
# Étape 217: Action = 4, Récompense = -10
# Étape 218: Action = 0, Récompense = -1
# Étape 219: Action = 2, Récompense = -1
# Étape 220: Action = 2, Récompense = -1
# Étape 221: Action = 4, Récompense = -10
# Étape 222: Action = 2, Récompense = -1
# Étape 223: Action = 1, Récompense = -1
# Étape 224: Action = 1, Récompense = -1
# Étape 225: Action = 5, Récompense = -10
# Étape 226: Action = 3, Récompense = -1
# Étape 227: Action = 0, Récompense = -1
# Étape 228: Action = 2, Récompense = -1
# Étape 229: Action = 5, Récompense = -10
# Étape 230: Action = 0, Récompense = -1
# Étape 231: Action = 0, Récompense = -1
# Étape 232: Action = 5, Récompense = -10
# Étape 233: Action = 2, Récompense = -1
# Étape 234: Action = 4, Récompense = -10
# Étape 235: Action = 2, Récompense = -1
# Étape 236: Action = 3, Récompense = -1
# Étape 237: Action = 1, Récompense = -1
# Étape 238: Action = 0, Récompense = -1
# Étape 239: Action = 2, Récompense = -1
# Étape 240: Action = 1, Récompense = -1
# Étape 241: Action = 5, Récompense = -10
# Étape 242: Action = 0, Récompense = -1
# Étape 243: Action = 3, Récompense = -1
# Étape 244: Action = 0, Récompense = -1
# Étape 245: Action = 1, Récompense = -1
# Étape 246: Action = 5, Récompense = -10
# Étape 247: Action = 2, Récompense = -1
# Étape 248: Action = 1, Récompense = -1
# Étape 249: Action = 5, Récompense = -10
# Étape 250: Action = 1, Récompense = -1
# Étape 251: Action = 3, Récompense = -1
# Étape 252: Action = 2, Récompense = -1
# Étape 253: Action = 5, Récompense = -10
# Étape 254: Action = 3, Récompense = -1
# Étape 255: Action = 0, Récompense = -1
# Étape 256: Action = 2, Récompense = -1
# Étape 257: Action = 0, Récompense = -1
# Étape 258: Action = 3, Récompense = -1
# Étape 259: Action = 1, Récompense = -1
# Étape 260: Action = 3, Récompense = -1
# Étape 261: Action = 3, Récompense = -1
# Étape 262: Action = 5, Récompense = -10
# Étape 263: Action = 1, Récompense = -1
# Étape 264: Action = 2, Récompense = -1
# Étape 265: Action = 5, Récompense = -10
# Étape 266: Action = 3, Récompense = -1
# Étape 267: Action = 2, Récompense = -1
# Étape 268: Action = 3, Récompense = -1
# Étape 269: Action = 4, Récompense = -10
# Étape 270: Action = 4, Récompense = -10
# Étape 271: Action = 5, Récompense = -10
# Étape 272: Action = 0, Récompense = -1
# Étape 273: Action = 5, Récompense = -10
# Étape 274: Action = 2, Récompense = -1
# Étape 275: Action = 1, Récompense = -1
# Étape 276: Action = 2, Récompense = -1
# Étape 277: Action = 1, Récompense = -1
# Étape 278: Action = 4, Récompense = -10
# Étape 279: Action = 5, Récompense = -10
# Étape 280: Action = 2, Récompense = -1
# Étape 281: Action = 4, Récompense = -10
# Étape 282: Action = 0, Récompense = -1
# Étape 283: Action = 4, Récompense = -10
# Étape 284: Action = 5, Récompense = -10
# Étape 285: Action = 0, Récompense = -1
# Étape 286: Action = 2, Récompense = -1
# Étape 287: Action = 2, Récompense = -1
# Étape 288: Action = 1, Récompense = -1
# Étape 289: Action = 5, Récompense = -10
# Étape 290: Action = 1, Récompense = -1
# Étape 291: Action = 5, Récompense = -10
# Étape 292: Action = 5, Récompense = -10
# Étape 293: Action = 4, Récompense = -10
# Étape 294: Action = 4, Récompense = -10
# Étape 295: Action = 5, Récompense = -10
# Étape 296: Action = 3, Récompense = -1
# Étape 297: Action = 5, Récompense = -10
# Étape 298: Action = 3, Récompense = -1
# Étape 299: Action = 1, Récompense = -1
# Étape 300: Action = 4, Récompense = -10
# Étape 301: Action = 1, Récompense = -1
# Étape 302: Action = 5, Récompense = -10
# Étape 303: Action = 4, Récompense = -10
# Étape 304: Action = 5, Récompense = -10
# Étape 305: Action = 4, Récompense = -10
# Étape 306: Action = 2, Récompense = -1
# Étape 307: Action = 3, Récompense = -1
# Étape 308: Action = 3, Récompense = -1
# Étape 309: Action = 3, Récompense = -1
# Étape 310: Action = 0, Récompense = -1
# Étape 311: Action = 3, Récompense = -1
# Étape 312: Action = 5, Récompense = -10
# Étape 313: Action = 2, Récompense = -1
# Étape 314: Action = 0, Récompense = -1
# Étape 315: Action = 2, Récompense = -1
# Étape 316: Action = 5, Récompense = -10
# Étape 317: Action = 1, Récompense = -1
# Étape 318: Action = 0, Récompense = -1
# Étape 319: Action = 0, Récompense = -1
# Étape 320: Action = 0, Récompense = -1
# Étape 321: Action = 0, Récompense = -1
# Étape 322: Action = 1, Récompense = -1
# Étape 323: Action = 2, Récompense = -1
# Étape 324: Action = 0, Récompense = -1
# Étape 325: Action = 1, Récompense = -1
# Étape 326: Action = 4, Récompense = -10
# Étape 327: Action = 0, Récompense = -1
# Étape 328: Action = 4, Récompense = -10
# Étape 329: Action = 3, Récompense = -1
# Étape 330: Action = 3, Récompense = -1
# Étape 331: Action = 5, Récompense = -10
# Étape 332: Action = 2, Récompense = -1
# Étape 333: Action = 3, Récompense = -1
# Étape 334: Action = 4, Récompense = -1
# Étape 335: Action = 4, Récompense = -10
# Étape 336: Action = 4, Récompense = -10
# Étape 337: Action = 0, Récompense = -1
# Étape 338: Action = 5, Récompense = -1
# Étape 339: Action = 5, Récompense = -10
# Étape 340: Action = 3, Récompense = -1
# Étape 341: Action = 4, Récompense = -1
# Étape 342: Action = 1, Récompense = -1
# Étape 343: Action = 5, Récompense = -10
# Étape 344: Action = 5, Récompense = -10
# Étape 345: Action = 2, Récompense = -1
# Étape 346: Action = 0, Récompense = -1
# Étape 347: Action = 4, Récompense = -10
# Étape 348: Action = 1, Récompense = -1
# Étape 349: Action = 2, Récompense = -1
# Étape 350: Action = 0, Récompense = -1
# Étape 351: Action = 0, Récompense = -1
# Étape 352: Action = 1, Récompense = -1
# Étape 353: Action = 0, Récompense = -1
# Étape 354: Action = 3, Récompense = -1
# Étape 355: Action = 0, Récompense = -1
# Étape 356: Action = 2, Récompense = -1
# Étape 357: Action = 2, Récompense = -1
# Étape 358: Action = 4, Récompense = -10
# Étape 359: Action = 2, Récompense = -1
# Étape 360: Action = 1, Récompense = -1
# Étape 361: Action = 3, Récompense = -1
# Étape 362: Action = 1, Récompense = -1
# Étape 363: Action = 1, Récompense = -1
# Étape 364: Action = 5, Récompense = -10
# Étape 365: Action = 5, Récompense = -10
# Étape 366: Action = 0, Récompense = -1
# Étape 367: Action = 2, Récompense = -1
# Étape 368: Action = 0, Récompense = -1
# Étape 369: Action = 5, Récompense = -10
# Étape 370: Action = 4, Récompense = -10
# Étape 371: Action = 3, Récompense = -1
# Étape 372: Action = 2, Récompense = -1
# Étape 373: Action = 3, Récompense = -1
# Étape 374: Action = 3, Récompense = -1
# Étape 375: Action = 5, Récompense = -10
# Étape 376: Action = 2, Récompense = -1
# Étape 377: Action = 0, Récompense = -1
# Étape 378: Action = 5, Récompense = -10
# Étape 379: Action = 1, Récompense = -1
# Étape 380: Action = 4, Récompense = -10
# Étape 381: Action = 1, Récompense = -1
# Étape 382: Action = 1, Récompense = -1
# Étape 383: Action = 4, Récompense = -10
# Étape 384: Action = 0, Récompense = -1
# Étape 385: Action = 0, Récompense = -1
# Étape 386: Action = 0, Récompense = -1
# Étape 387: Action = 5, Récompense = -10
# Étape 388: Action = 2, Récompense = -1
# Étape 389: Action = 1, Récompense = -1
# Étape 390: Action = 1, Récompense = -1
# Étape 391: Action = 4, Récompense = -10
# Étape 392: Action = 4, Récompense = -10
# Étape 393: Action = 0, Récompense = -1
# Étape 394: Action = 3, Récompense = -1
# Étape 395: Action = 1, Récompense = -1
# Étape 396: Action = 0, Récompense = -1
# Étape 397: Action = 0, Récompense = -1
# Étape 398: Action = 0, Récompense = -1
# Étape 399: Action = 2, Récompense = -1
# Étape 400: Action = 5, Récompense = -10
# Étape 401: Action = 1, Récompense = -1
# Étape 402: Action = 0, Récompense = -1
# Étape 403: Action = 4, Récompense = -10
# Étape 404: Action = 3, Récompense = -1
# Étape 405: Action = 1, Récompense = -1
# Étape 406: Action = 0, Récompense = -1
# Étape 407: Action = 0, Récompense = -1
# Étape 408: Action = 0, Récompense = -1
# Étape 409: Action = 0, Récompense = -1
# Étape 410: Action = 4, Récompense = -10
# Étape 411: Action = 5, Récompense = -1
# Étape 412: Action = 3, Récompense = -1
# Étape 413: Action = 1, Récompense = -1
# Étape 414: Action = 4, Récompense = -10
# Étape 415: Action = 4, Récompense = -10
# Étape 416: Action = 0, Récompense = -1
# Étape 417: Action = 1, Récompense = -1
# Étape 418: Action = 3, Récompense = -1
# Étape 419: Action = 5, Récompense = -10
# Étape 420: Action = 4, Récompense = -10
# Étape 421: Action = 2, Récompense = -1
# Étape 422: Action = 0, Récompense = -1
# Étape 423: Action = 4, Récompense = -10
# Étape 424: Action = 2, Récompense = -1
# Étape 425: Action = 1, Récompense = -1
# Étape 426: Action = 5, Récompense = -10
# Étape 427: Action = 4, Récompense = -10
# Étape 428: Action = 1, Récompense = -1
# Étape 429: Action = 0, Récompense = -1
# Étape 430: Action = 5, Récompense = -10
# Étape 431: Action = 1, Récompense = -1
# Étape 432: Action = 5, Récompense = -10
# Étape 433: Action = 0, Récompense = -1
# Étape 434: Action = 5, Récompense = -10
# Étape 435: Action = 4, Récompense = -10
# Étape 436: Action = 5, Récompense = -10
# Étape 437: Action = 2, Récompense = -1
# Étape 438: Action = 3, Récompense = -1
# Étape 439: Action = 3, Récompense = -1
# Étape 440: Action = 1, Récompense = -1
# Étape 441: Action = 0, Récompense = -1
# Étape 442: Action = 0, Récompense = -1
# Étape 443: Action = 3, Récompense = -1
# Étape 444: Action = 4, Récompense = -1
# Étape 445: Action = 4, Récompense = -10
# Étape 446: Action = 1, Récompense = -1
# Étape 447: Action = 1, Récompense = -1
# Étape 448: Action = 4, Récompense = -10
# Étape 449: Action = 0, Récompense = -1
# Étape 450: Action = 0, Récompense = -1
# Étape 451: Action = 0, Récompense = -1
# Étape 452: Action = 3, Récompense = -1
# Étape 453: Action = 3, Récompense = -1
# Étape 454: Action = 0, Récompense = -1
# Étape 455: Action = 3, Récompense = -1
# Étape 456: Action = 4, Récompense = -10
# Étape 457: Action = 4, Récompense = -10
# Étape 458: Action = 5, Récompense = -1
# Étape 459: Action = 5, Récompense = -10
# Étape 460: Action = 5, Récompense = -10
# Étape 461: Action = 2, Récompense = -1
# Étape 462: Action = 5, Récompense = -10
# Étape 463: Action = 3, Récompense = -1
# Étape 464: Action = 0, Récompense = -1
# Étape 465: Action = 1, Récompense = -1
# Étape 466: Action = 0, Récompense = -1
# Étape 467: Action = 2, Récompense = -1
# Étape 468: Action = 5, Récompense = -10
# Étape 469: Action = 2, Récompense = -1
# Étape 470: Action = 4, Récompense = -10
# Étape 471: Action = 3, Récompense = -1
# Étape 472: Action = 0, Récompense = -1
# Étape 473: Action = 4, Récompense = -1
# Étape 474: Action = 5, Récompense = -1
# Étape 475: Action = 0, Récompense = -1
# Étape 476: Action = 0, Récompense = -1
# Étape 477: Action = 4, Récompense = -1
# Étape 478: Action = 1, Récompense = -1
# Étape 479: Action = 4, Récompense = -10
# Étape 480: Action = 5, Récompense = -10
# Étape 481: Action = 4, Récompense = -10
# Étape 482: Action = 5, Récompense = -10
# Étape 483: Action = 1, Récompense = -1
# Étape 484: Action = 2, Récompense = -1
# Étape 485: Action = 4, Récompense = -10
# Étape 486: Action = 5, Récompense = -10
# Étape 487: Action = 4, Récompense = -10
# Étape 488: Action = 1, Récompense = -1
# Étape 489: Action = 0, Récompense = -1
# Étape 490: Action = 5, Récompense = -10
# Étape 491: Action = 2, Récompense = -1
# Étape 492: Action = 1, Récompense = -1
# Étape 493: Action = 0, Récompense = -1
# Étape 494: Action = 0, Récompense = -1
# Étape 495: Action = 2, Récompense = -1
# Étape 496: Action = 2, Récompense = -1
# Étape 497: Action = 4, Récompense = -10
# Étape 498: Action = 2, Récompense = -1
# Étape 499: Action = 2, Récompense = -1
# Étape 500: Action = 2, Récompense = -1
# Étape 501: Action = 2, Récompense = -1
# Étape 502: Action = 3, Récompense = -1
# Étape 503: Action = 0, Récompense = -1
# Étape 504: Action = 2, Récompense = -1
# Étape 505: Action = 5, Récompense = -10
# Étape 506: Action = 2, Récompense = -1
# Étape 507: Action = 0, Récompense = -1
# Étape 508: Action = 2, Récompense = -1
# Étape 509: Action = 3, Récompense = -1
# Étape 510: Action = 4, Récompense = -10
# Étape 511: Action = 2, Récompense = -1
# Étape 512: Action = 2, Récompense = -1
# Étape 513: Action = 4, Récompense = -10
# Étape 514: Action = 3, Récompense = -1
# Étape 515: Action = 1, Récompense = -1
# Étape 516: Action = 1, Récompense = -1
# Étape 517: Action = 4, Récompense = -10
# Étape 518: Action = 5, Récompense = -10
# Étape 519: Action = 4, Récompense = -10
# Étape 520: Action = 1, Récompense = -1
# Étape 521: Action = 0, Récompense = -1
# Étape 522: Action = 2, Récompense = -1
# Étape 523: Action = 0, Récompense = -1
# Étape 524: Action = 0, Récompense = -1
# Étape 525: Action = 4, Récompense = -10
# Étape 526: Action = 3, Récompense = -1
# Étape 527: Action = 1, Récompense = -1
# Étape 528: Action = 4, Récompense = -10
# Étape 529: Action = 5, Récompense = -10
# Étape 530: Action = 0, Récompense = -1
# Étape 531: Action = 2, Récompense = -1
# Étape 532: Action = 4, Récompense = -10
# Étape 533: Action = 4, Récompense = -10
# Étape 534: Action = 3, Récompense = -1
# Étape 535: Action = 3, Récompense = -1
# Étape 536: Action = 5, Récompense = -1
# Étape 537: Action = 2, Récompense = -1
# Étape 538: Action = 2, Récompense = -1
# Étape 539: Action = 3, Récompense = -1
# Étape 540: Action = 3, Récompense = -1
# Étape 541: Action = 5, Récompense = -10
# Étape 542: Action = 3, Récompense = -1
# Étape 543: Action = 2, Récompense = -1
# Étape 544: Action = 4, Récompense = -10
# Étape 545: Action = 3, Récompense = -1
# Étape 546: Action = 4, Récompense = -1
# Étape 547: Action = 2, Récompense = -1
# Étape 548: Action = 0, Récompense = -1
# Étape 549: Action = 2, Récompense = -1
# Étape 550: Action = 1, Récompense = -1
# Étape 551: Action = 3, Récompense = -1
# Étape 552: Action = 1, Récompense = -1
# Étape 553: Action = 5, Récompense = -10
# Étape 554: Action = 0, Récompense = -1
# Étape 555: Action = 5, Récompense = -10
# Étape 556: Action = 3, Récompense = -1
# Étape 557: Action = 3, Récompense = -1
# Étape 558: Action = 2, Récompense = -1
# Étape 559: Action = 3, Récompense = -1
# Étape 560: Action = 3, Récompense = -1
# Étape 561: Action = 0, Récompense = -1
# Étape 562: Action = 5, Récompense = -1
# Étape 563: Action = 2, Récompense = -1
# Étape 564: Action = 1, Récompense = -1
# Étape 565: Action = 1, Récompense = -1
# Étape 566: Action = 1, Récompense = -1
# Étape 567: Action = 3, Récompense = -1
# Étape 568: Action = 0, Récompense = -1
# Étape 569: Action = 1, Récompense = -1
# Étape 570: Action = 5, Récompense = -10
# Étape 571: Action = 3, Récompense = -1
# Étape 572: Action = 2, Récompense = -1
# Étape 573: Action = 0, Récompense = -1
# Étape 574: Action = 4, Récompense = -10
# Étape 575: Action = 0, Récompense = -1
# Étape 576: Action = 4, Récompense = -10
# Étape 577: Action = 2, Récompense = -1
# Étape 578: Action = 2, Récompense = -1
# Étape 579: Action = 5, Récompense = -10
# Étape 580: Action = 1, Récompense = -1
# Étape 581: Action = 3, Récompense = -1
# Étape 582: Action = 5, Récompense = -10
# Étape 583: Action = 3, Récompense = -1
# Étape 584: Action = 3, Récompense = -1
# Étape 585: Action = 0, Récompense = -1
# Étape 586: Action = 0, Récompense = -1
# Étape 587: Action = 1, Récompense = -1
# Étape 588: Action = 1, Récompense = -1
# Étape 589: Action = 5, Récompense = -10
# Étape 590: Action = 3, Récompense = -1
# Étape 591: Action = 0, Récompense = -1
# Étape 592: Action = 0, Récompense = -1
# Étape 593: Action = 1, Récompense = -1
# Étape 594: Action = 4, Récompense = -10
# Étape 595: Action = 2, Récompense = -1
# Étape 596: Action = 3, Récompense = -1
# Étape 597: Action = 2, Récompense = -1
# Étape 598: Action = 5, Récompense = -10
# Étape 599: Action = 1, Récompense = -1
# Étape 600: Action = 4, Récompense = -10
# Étape 601: Action = 1, Récompense = -1
# Étape 602: Action = 0, Récompense = -1
# Étape 603: Action = 5, Récompense = -10
# Étape 604: Action = 3, Récompense = -1
# Étape 605: Action = 3, Récompense = -1
# Étape 606: Action = 0, Récompense = -1
# Étape 607: Action = 4, Récompense = -10
# Étape 608: Action = 1, Récompense = -1
# Étape 609: Action = 3, Récompense = -1
# Étape 610: Action = 0, Récompense = -1
# Étape 611: Action = 1, Récompense = -1
# Étape 612: Action = 3, Récompense = -1
# Étape 613: Action = 3, Récompense = -1
# Étape 614: Action = 4, Récompense = -10
# Étape 615: Action = 3, Récompense = -1
# Étape 616: Action = 1, Récompense = -1
# Étape 617: Action = 2, Récompense = -1
# Étape 618: Action = 2, Récompense = -1
# Étape 619: Action = 2, Récompense = -1
# Étape 620: Action = 3, Récompense = -1
# Étape 621: Action = 3, Récompense = -1
# Étape 622: Action = 1, Récompense = -1
# Étape 623: Action = 5, Récompense = -10
# Étape 624: Action = 4, Récompense = -10
# Étape 625: Action = 5, Récompense = -10
# Étape 626: Action = 4, Récompense = -10
# Étape 627: Action = 0, Récompense = -1
# Étape 628: Action = 5, Récompense = -10
# Étape 629: Action = 4, Récompense = -10
# Étape 630: Action = 2, Récompense = -1
# Étape 631: Action = 0, Récompense = -1
# Étape 632: Action = 5, Récompense = -10
# Étape 633: Action = 3, Récompense = -1
# Étape 634: Action = 5, Récompense = -10
# Étape 635: Action = 3, Récompense = -1
# Étape 636: Action = 0, Récompense = -1
# Étape 637: Action = 5, Récompense = -10
# Étape 638: Action = 3, Récompense = -1
# Étape 639: Action = 0, Récompense = -1
# Étape 640: Action = 4, Récompense = -10
# Étape 641: Action = 1, Récompense = -1
# Étape 642: Action = 0, Récompense = -1
# Étape 643: Action = 0, Récompense = -1
# Étape 644: Action = 5, Récompense = -10
# Étape 645: Action = 2, Récompense = -1
# Étape 646: Action = 1, Récompense = -1
# Étape 647: Action = 3, Récompense = -1
# Étape 648: Action = 3, Récompense = -1
# Étape 649: Action = 2, Récompense = -1
# Étape 650: Action = 4, Récompense = -10
# Étape 651: Action = 0, Récompense = -1
# Étape 652: Action = 1, Récompense = -1
# Étape 653: Action = 0, Récompense = -1
# Étape 654: Action = 4, Récompense = -10
# Étape 655: Action = 1, Récompense = -1
# Étape 656: Action = 3, Récompense = -1
# Étape 657: Action = 4, Récompense = -10
# Étape 658: Action = 1, Récompense = -1
# Étape 659: Action = 3, Récompense = -1
# Étape 660: Action = 2, Récompense = -1
# Étape 661: Action = 3, Récompense = -1
# Étape 662: Action = 3, Récompense = -1
# Étape 663: Action = 3, Récompense = -1
# Étape 664: Action = 0, Récompense = -1
# Étape 665: Action = 4, Récompense = -10
# Étape 666: Action = 5, Récompense = -10
# Étape 667: Action = 5, Récompense = -10
# Étape 668: Action = 5, Récompense = -10
# Étape 669: Action = 2, Récompense = -1
# Étape 670: Action = 0, Récompense = -1
# Étape 671: Action = 3, Récompense = -1
# Étape 672: Action = 0, Récompense = -1
# Étape 673: Action = 5, Récompense = -10
# Étape 674: Action = 1, Récompense = -1
# Étape 675: Action = 2, Récompense = -1
# Étape 676: Action = 5, Récompense = -10
# Étape 677: Action = 4, Récompense = -10
# Étape 678: Action = 4, Récompense = -10
# Étape 679: Action = 5, Récompense = -10
# Étape 680: Action = 2, Récompense = -1
# Étape 681: Action = 1, Récompense = -1
# Étape 682: Action = 1, Récompense = -1
# Étape 683: Action = 4, Récompense = -10
# Étape 684: Action = 2, Récompense = -1
# Étape 685: Action = 1, Récompense = -1
# Étape 686: Action = 2, Récompense = -1
# Étape 687: Action = 1, Récompense = -1
# Étape 688: Action = 3, Récompense = -1
# Étape 689: Action = 4, Récompense = -10
# Étape 690: Action = 2, Récompense = -1
# Étape 691: Action = 0, Récompense = -1
# Étape 692: Action = 5, Récompense = -10
# Étape 693: Action = 0, Récompense = -1
# Étape 694: Action = 1, Récompense = -1
# Étape 695: Action = 1, Récompense = -1
# Étape 696: Action = 4, Récompense = -10
# Étape 697: Action = 4, Récompense = -10
# Étape 698: Action = 0, Récompense = -1
# Étape 699: Action = 1, Récompense = -1
# Étape 700: Action = 0, Récompense = -1
# Étape 701: Action = 4, Récompense = -10
# Étape 702: Action = 1, Récompense = -1
# Étape 703: Action = 1, Récompense = -1
# Étape 704: Action = 3, Récompense = -1
# Étape 705: Action = 1, Récompense = -1
# Étape 706: Action = 0, Récompense = -1
# Étape 707: Action = 3, Récompense = -1
# Étape 708: Action = 3, Récompense = -1
# Étape 709: Action = 2, Récompense = -1
# Étape 710: Action = 4, Récompense = -10
# Étape 711: Action = 1, Récompense = -1
# Étape 712: Action = 2, Récompense = -1
# Étape 713: Action = 5, Récompense = -10
# Étape 714: Action = 4, Récompense = -10
# Étape 715: Action = 1, Récompense = -1
# Étape 716: Action = 3, Récompense = -1
# Étape 717: Action = 4, Récompense = -10
# Étape 718: Action = 4, Récompense = -10
# Étape 719: Action = 0, Récompense = -1
# Étape 720: Action = 1, Récompense = -1
# Étape 721: Action = 1, Récompense = -1
# Étape 722: Action = 1, Récompense = -1
# Étape 723: Action = 3, Récompense = -1
# Étape 724: Action = 1, Récompense = -1
# Étape 725: Action = 0, Récompense = -1
# Étape 726: Action = 0, Récompense = -1
# Étape 727: Action = 1, Récompense = -1
# Étape 728: Action = 4, Récompense = -10
# Étape 729: Action = 0, Récompense = -1
# Étape 730: Action = 2, Récompense = -1
# Étape 731: Action = 3, Récompense = -1
# Étape 732: Action = 3, Récompense = -1
# Étape 733: Action = 4, Récompense = -10
# Étape 734: Action = 3, Récompense = -1
# Étape 735: Action = 5, Récompense = -10
# Étape 736: Action = 4, Récompense = -10
# Étape 737: Action = 5, Récompense = -10
# Étape 738: Action = 2, Récompense = -1
# Étape 739: Action = 5, Récompense = -10
# Étape 740: Action = 5, Récompense = -10
# Étape 741: Action = 3, Récompense = -1
# Étape 742: Action = 1, Récompense = -1
# Étape 743: Action = 0, Récompense = -1
# Étape 744: Action = 1, Récompense = -1
# Étape 745: Action = 0, Récompense = -1
# Étape 746: Action = 3, Récompense = -1
# Étape 747: Action = 1, Récompense = -1
# Étape 748: Action = 2, Récompense = -1
# Étape 749: Action = 3, Récompense = -1
# Étape 750: Action = 4, Récompense = -10
# Étape 751: Action = 3, Récompense = -1
# Étape 752: Action = 3, Récompense = -1
# Étape 753: Action = 3, Récompense = -1
# Étape 754: Action = 5, Récompense = -10
# Étape 755: Action = 4, Récompense = -10
# Étape 756: Action = 2, Récompense = -1
# Étape 757: Action = 0, Récompense = -1
# Étape 758: Action = 3, Récompense = -1
# Étape 759: Action = 1, Récompense = -1
# Étape 760: Action = 0, Récompense = -1
# Étape 761: Action = 2, Récompense = -1
# Étape 762: Action = 2, Récompense = -1
# Étape 763: Action = 3, Récompense = -1
# Étape 764: Action = 0, Récompense = -1
# Étape 765: Action = 1, Récompense = -1
# Étape 766: Action = 4, Récompense = -10
# Étape 767: Action = 0, Récompense = -1
# Étape 768: Action = 2, Récompense = -1
# Étape 769: Action = 2, Récompense = -1
# Étape 770: Action = 0, Récompense = -1
# Étape 771: Action = 2, Récompense = -1
# Étape 772: Action = 5, Récompense = -10
# Étape 773: Action = 1, Récompense = -1
# Étape 774: Action = 2, Récompense = -1
# Étape 775: Action = 4, Récompense = -10
# Étape 776: Action = 4, Récompense = -10
# Étape 777: Action = 4, Récompense = -10
# Étape 778: Action = 5, Récompense = -10
# Étape 779: Action = 0, Récompense = -1
# Étape 780: Action = 1, Récompense = -1
# Étape 781: Action = 4, Récompense = -10
# Étape 782: Action = 3, Récompense = -1
# Étape 783: Action = 2, Récompense = -1
# Étape 784: Action = 0, Récompense = -1
# Étape 785: Action = 2, Récompense = -1
# Étape 786: Action = 5, Récompense = -10
# Étape 787: Action = 4, Récompense = -10
# Étape 788: Action = 4, Récompense = -10
# Étape 789: Action = 3, Récompense = -1
# Étape 790: Action = 5, Récompense = -10
# Étape 791: Action = 1, Récompense = -1
# Étape 792: Action = 3, Récompense = -1
# Étape 793: Action = 1, Récompense = -1
# Étape 794: Action = 1, Récompense = -1
# Étape 795: Action = 1, Récompense = -1
# Étape 796: Action = 2, Récompense = -1
# Étape 797: Action = 4, Récompense = -10
# Étape 798: Action = 4, Récompense = -10
# Étape 799: Action = 5, Récompense = -10
# Étape 800: Action = 3, Récompense = -1
# Étape 801: Action = 0, Récompense = -1
# Étape 802: Action = 3, Récompense = -1
# Étape 803: Action = 3, Récompense = -1
# Étape 804: Action = 5, Récompense = -10
# Étape 805: Action = 0, Récompense = -1
# Étape 806: Action = 1, Récompense = -1
# Étape 807: Action = 2, Récompense = -1
# Étape 808: Action = 3, Récompense = -1
# Étape 809: Action = 4, Récompense = -10
# Étape 810: Action = 4, Récompense = -10
# Étape 811: Action = 1, Récompense = -1
# Étape 812: Action = 2, Récompense = -1
# Étape 813: Action = 4, Récompense = -10
# Étape 814: Action = 2, Récompense = -1
# Étape 815: Action = 2, Récompense = -1
# Étape 816: Action = 4, Récompense = -10
# Étape 817: Action = 1, Récompense = -1
# Étape 818: Action = 3, Récompense = -1
# Étape 819: Action = 2, Récompense = -1
# Étape 820: Action = 5, Récompense = -10
# Étape 821: Action = 5, Récompense = -10
# Étape 822: Action = 0, Récompense = -1
# Étape 823: Action = 5, Récompense = -10
# Étape 824: Action = 5, Récompense = -10
# Étape 825: Action = 4, Récompense = -10
# Étape 826: Action = 2, Récompense = -1
# Étape 827: Action = 0, Récompense = -1
# Étape 828: Action = 5, Récompense = -10
# Étape 829: Action = 0, Récompense = -1
# Étape 830: Action = 2, Récompense = -1
# Étape 831: Action = 4, Récompense = -10
# Étape 832: Action = 0, Récompense = -1
# Étape 833: Action = 4, Récompense = -10
# Étape 834: Action = 4, Récompense = -10
# Étape 835: Action = 0, Récompense = -1
# Étape 836: Action = 4, Récompense = -10
# Étape 837: Action = 1, Récompense = -1
# Étape 838: Action = 5, Récompense = -10
# Étape 839: Action = 5, Récompense = -10
# Étape 840: Action = 0, Récompense = -1
# Étape 841: Action = 5, Récompense = -10
# Étape 842: Action = 2, Récompense = -1
# Étape 843: Action = 1, Récompense = -1
# Étape 844: Action = 5, Récompense = -10
# Étape 845: Action = 4, Récompense = -10
# Étape 846: Action = 1, Récompense = -1
# Étape 847: Action = 5, Récompense = -10
# Étape 848: Action = 0, Récompense = -1
# Étape 849: Action = 3, Récompense = -1
# Étape 850: Action = 3, Récompense = -1
# Étape 851: Action = 3, Récompense = -1
# Étape 852: Action = 5, Récompense = -10
# Étape 853: Action = 1, Récompense = -1
# Étape 854: Action = 5, Récompense = -10
# Étape 855: Action = 2, Récompense = -1
# Étape 856: Action = 4, Récompense = -10
# Étape 857: Action = 2, Récompense = -1
# Étape 858: Action = 3, Récompense = -1
# Étape 859: Action = 0, Récompense = -1
# Étape 860: Action = 0, Récompense = -1
# Étape 861: Action = 0, Récompense = -1
# Étape 862: Action = 5, Récompense = -10
# Étape 863: Action = 4, Récompense = -10
# Étape 864: Action = 1, Récompense = -1
# Étape 865: Action = 1, Récompense = -1
# Étape 866: Action = 3, Récompense = -1
# Étape 867: Action = 3, Récompense = -1
# Étape 868: Action = 3, Récompense = -1
# Étape 869: Action = 1, Récompense = -1
# Étape 870: Action = 0, Récompense = -1
# Étape 871: Action = 3, Récompense = -1
# Étape 872: Action = 3, Récompense = -1
# Étape 873: Action = 1, Récompense = -1
# Étape 874: Action = 4, Récompense = -10
# Étape 875: Action = 1, Récompense = -1
# Étape 876: Action = 5, Récompense = -10
# Étape 877: Action = 0, Récompense = -1
# Étape 878: Action = 5, Récompense = -10
# Étape 879: Action = 1, Récompense = -1
# Étape 880: Action = 4, Récompense = -10
# Étape 881: Action = 2, Récompense = -1
# Étape 882: Action = 2, Récompense = -1
# Étape 883: Action = 1, Récompense = -1
# Étape 884: Action = 0, Récompense = -1
# Étape 885: Action = 3, Récompense = -1
# Étape 886: Action = 3, Récompense = -1
# Étape 887: Action = 1, Récompense = -1
# Étape 888: Action = 0, Récompense = -1
# Étape 889: Action = 0, Récompense = -1
# Étape 890: Action = 0, Récompense = -1
# Étape 891: Action = 4, Récompense = -10
# Étape 892: Action = 4, Récompense = -10
# Étape 893: Action = 2, Récompense = -1
# Étape 894: Action = 0, Récompense = -1
# Étape 895: Action = 1, Récompense = -1
# Étape 896: Action = 4, Récompense = -10
# Étape 897: Action = 2, Récompense = -1
# Étape 898: Action = 1, Récompense = -1
# Étape 899: Action = 4, Récompense = -10
# Étape 900: Action = 0, Récompense = -1
# Étape 901: Action = 3, Récompense = -1
# Étape 902: Action = 2, Récompense = -1
# Étape 903: Action = 2, Récompense = -1
# Étape 904: Action = 1, Récompense = -1
# Étape 905: Action = 1, Récompense = -1
# Étape 906: Action = 1, Récompense = -1
# Étape 907: Action = 2, Récompense = -1
# Étape 908: Action = 3, Récompense = -1
# Étape 909: Action = 1, Récompense = -1
# Étape 910: Action = 1, Récompense = -1
# Étape 911: Action = 5, Récompense = -10
# Étape 912: Action = 0, Récompense = -1
# Étape 913: Action = 3, Récompense = -1
# Étape 914: Action = 0, Récompense = -1
# Étape 915: Action = 4, Récompense = -10
# Étape 916: Action = 1, Récompense = -1
# Étape 917: Action = 1, Récompense = -1
# Étape 918: Action = 1, Récompense = -1
# Étape 919: Action = 5, Récompense = -10
# Étape 920: Action = 2, Récompense = -1
# Étape 921: Action = 5, Récompense = -10
# Étape 922: Action = 0, Récompense = -1
# Étape 923: Action = 1, Récompense = -1
# Étape 924: Action = 4, Récompense = -10
# Étape 925: Action = 5, Récompense = -10
# Étape 926: Action = 4, Récompense = -10
# Étape 927: Action = 4, Récompense = -10
# Étape 928: Action = 5, Récompense = -10
# Étape 929: Action = 3, Récompense = -1
# Étape 930: Action = 3, Récompense = -1
# Étape 931: Action = 1, Récompense = -1
# Étape 932: Action = 1, Récompense = -1
# Étape 933: Action = 2, Récompense = -1
# Étape 934: Action = 3, Récompense = -1
# Étape 935: Action = 4, Récompense = -10
# Étape 936: Action = 5, Récompense = -10
# Étape 937: Action = 5, Récompense = -10
# Étape 938: Action = 1, Récompense = -1
# Étape 939: Action = 1, Récompense = -1
# Étape 940: Action = 5, Récompense = -10
# Étape 941: Action = 1, Récompense = -1
# Étape 942: Action = 4, Récompense = -10
# Étape 943: Action = 5, Récompense = -10
# Étape 944: Action = 2, Récompense = -1
# Étape 945: Action = 5, Récompense = -10
# Étape 946: Action = 5, Récompense = -10
# Étape 947: Action = 1, Récompense = -1
# Étape 948: Action = 3, Récompense = -1
# Étape 949: Action = 1, Récompense = -1
# Étape 950: Action = 2, Récompense = -1
# Étape 951: Action = 3, Récompense = -1
# Étape 952: Action = 0, Récompense = -1
# Étape 953: Action = 3, Récompense = -1
# Étape 954: Action = 3, Récompense = -1
# Étape 955: Action = 4, Récompense = -10
# Étape 956: Action = 5, Récompense = -10
# Étape 957: Action = 1, Récompense = -1
# Étape 958: Action = 2, Récompense = -1
# Étape 959: Action = 1, Récompense = -1
# Étape 960: Action = 4, Récompense = -10
# Étape 961: Action = 5, Récompense = -10
# Étape 962: Action = 0, Récompense = -1
# Étape 963: Action = 4, Récompense = -10
# Étape 964: Action = 0, Récompense = -1
# Étape 965: Action = 2, Récompense = -1
# Étape 966: Action = 0, Récompense = -1
# Étape 967: Action = 1, Récompense = -1
# Étape 968: Action = 2, Récompense = -1
# Étape 969: Action = 1, Récompense = -1
# Étape 970: Action = 5, Récompense = -10
# Étape 971: Action = 0, Récompense = -1
# Étape 972: Action = 2, Récompense = -1
# Étape 973: Action = 4, Récompense = -10
# Étape 974: Action = 5, Récompense = -10
# Étape 975: Action = 0, Récompense = -1
# Étape 976: Action = 2, Récompense = -1
# Étape 977: Action = 1, Récompense = -1
# Étape 978: Action = 2, Récompense = -1
# Étape 979: Action = 3, Récompense = -1
# Étape 980: Action = 2, Récompense = -1
# Étape 981: Action = 4, Récompense = -10
# Étape 982: Action = 2, Récompense = -1
# Étape 983: Action = 0, Récompense = -1
# Étape 984: Action = 3, Récompense = -1
# Étape 985: Action = 0, Récompense = -1
# Étape 986: Action = 3, Récompense = -1
# Étape 987: Action = 0, Récompense = -1
# Étape 988: Action = 2, Récompense = -1
# Étape 989: Action = 5, Récompense = -10
# Étape 990: Action = 3, Récompense = -1
# Étape 991: Action = 3, Récompense = -1
# Étape 992: Action = 3, Récompense = -1
# Étape 993: Action = 0, Récompense = -1
# Étape 994: Action = 0, Récompense = -1
# Étape 995: Action = 1, Récompense = -1
# Étape 996: Action = 1, Récompense = -1
# Étape 997: Action = 4, Récompense = -10
# Étape 998: Action = 5, Récompense = -10
# Étape 999: Action = 4, Récompense = -10
# Étape 1000: Action = 0, Récompense = -1
# Étape 1001: Action = 2, Récompense = -1
# Étape 1002: Action = 3, Récompense = -1
# Étape 1003: Action = 3, Récompense = -1
# Étape 1004: Action = 1, Récompense = -1
# Étape 1005: Action = 3, Récompense = -1
# Étape 1006: Action = 1, Récompense = -1
# Étape 1007: Action = 4, Récompense = -10
# Étape 1008: Action = 0, Récompense = -1
# Étape 1009: Action = 2, Récompense = -1
# Étape 1010: Action = 0, Récompense = -1
# Étape 1011: Action = 1, Récompense = -1
# Étape 1012: Action = 0, Récompense = -1
# Étape 1013: Action = 5, Récompense = -10
# Étape 1014: Action = 1, Récompense = -1
# Étape 1015: Action = 5, Récompense = -10
# Étape 1016: Action = 2, Récompense = -1
# Étape 1017: Action = 4, Récompense = -10
# Étape 1018: Action = 1, Récompense = -1
# Étape 1019: Action = 3, Récompense = -1
# Étape 1020: Action = 5, Récompense = -10
# Étape 1021: Action = 4, Récompense = -10
# Étape 1022: Action = 0, Récompense = -1
# Étape 1023: Action = 1, Récompense = -1
# Étape 1024: Action = 0, Récompense = -1
# Étape 1025: Action = 2, Récompense = -1
# Étape 1026: Action = 1, Récompense = -1
# Étape 1027: Action = 0, Récompense = -1
# Étape 1028: Action = 3, Récompense = -1
# Étape 1029: Action = 4, Récompense = -10
# Étape 1030: Action = 5, Récompense = -10
# Étape 1031: Action = 5, Récompense = -10
# Étape 1032: Action = 3, Récompense = -1
# Étape 1033: Action = 4, Récompense = -10
# Étape 1034: Action = 1, Récompense = -1
# Étape 1035: Action = 1, Récompense = -1
# Étape 1036: Action = 4, Récompense = -10
# Étape 1037: Action = 2, Récompense = -1
# Étape 1038: Action = 0, Récompense = -1
# Étape 1039: Action = 1, Récompense = -1
# Étape 1040: Action = 1, Récompense = -1
# Étape 1041: Action = 4, Récompense = -10
# Étape 1042: Action = 1, Récompense = -1
# Étape 1043: Action = 4, Récompense = -10
# Étape 1044: Action = 0, Récompense = -1
# Étape 1045: Action = 4, Récompense = -10
# Étape 1046: Action = 4, Récompense = -10
# Étape 1047: Action = 5, Récompense = -10
# Étape 1048: Action = 2, Récompense = -1
# Étape 1049: Action = 1, Récompense = -1
# Étape 1050: Action = 5, Récompense = -10
# Étape 1051: Action = 4, Récompense = -10
# Étape 1052: Action = 1, Récompense = -1
# Étape 1053: Action = 5, Récompense = -10
# Étape 1054: Action = 4, Récompense = -10
# Étape 1055: Action = 3, Récompense = -1
# Étape 1056: Action = 4, Récompense = -10
# Étape 1057: Action = 5, Récompense = -10
# Étape 1058: Action = 4, Récompense = -10
# Étape 1059: Action = 2, Récompense = -1
# Étape 1060: Action = 2, Récompense = -1
# Étape 1061: Action = 4, Récompense = -10
# Étape 1062: Action = 3, Récompense = -1
# Étape 1063: Action = 0, Récompense = -1
# Étape 1064: Action = 0, Récompense = -1
# Étape 1065: Action = 0, Récompense = -1
# Étape 1066: Action = 1, Récompense = -1
# Étape 1067: Action = 5, Récompense = -10
# Étape 1068: Action = 2, Récompense = -1
# Étape 1069: Action = 5, Récompense = -10
# Étape 1070: Action = 1, Récompense = -1
# Étape 1071: Action = 1, Récompense = -1
# Étape 1072: Action = 2, Récompense = -1
# Étape 1073: Action = 3, Récompense = -1
# Étape 1074: Action = 5, Récompense = -10
# Étape 1075: Action = 5, Récompense = -10
# Étape 1076: Action = 4, Récompense = -10
# Étape 1077: Action = 5, Récompense = -10
# Étape 1078: Action = 3, Récompense = -1
# Étape 1079: Action = 3, Récompense = -1
# Étape 1080: Action = 2, Récompense = -1
# Étape 1081: Action = 1, Récompense = -1
# Étape 1082: Action = 3, Récompense = -1
# Étape 1083: Action = 1, Récompense = -1
# Étape 1084: Action = 4, Récompense = -10
# Étape 1085: Action = 4, Récompense = -10
# Étape 1086: Action = 1, Récompense = -1
# Étape 1087: Action = 2, Récompense = -1
# Étape 1088: Action = 2, Récompense = -1
# Étape 1089: Action = 4, Récompense = -10
# Étape 1090: Action = 0, Récompense = -1
# Étape 1091: Action = 5, Récompense = -10
# Étape 1092: Action = 5, Récompense = -10
# Étape 1093: Action = 4, Récompense = -10
# Étape 1094: Action = 0, Récompense = -1
# Étape 1095: Action = 5, Récompense = -10
# Étape 1096: Action = 0, Récompense = -1
# Étape 1097: Action = 2, Récompense = -1
# Étape 1098: Action = 4, Récompense = -10
# Étape 1099: Action = 4, Récompense = -10
# Étape 1100: Action = 4, Récompense = -10
# Étape 1101: Action = 3, Récompense = -1
# Étape 1102: Action = 1, Récompense = -1
# Étape 1103: Action = 0, Récompense = -1
# Étape 1104: Action = 1, Récompense = -1
# Étape 1105: Action = 4, Récompense = -10
# Étape 1106: Action = 5, Récompense = -10
# Étape 1107: Action = 0, Récompense = -1
# Étape 1108: Action = 4, Récompense = -10
# Étape 1109: Action = 2, Récompense = -1
# Étape 1110: Action = 4, Récompense = -10
# Étape 1111: Action = 0, Récompense = -1
# Étape 1112: Action = 1, Récompense = -1
# Étape 1113: Action = 0, Récompense = -1
# Étape 1114: Action = 1, Récompense = -1
# Étape 1115: Action = 1, Récompense = -1
# Étape 1116: Action = 3, Récompense = -1
# Étape 1117: Action = 4, Récompense = -10
# Étape 1118: Action = 0, Récompense = -1
# Étape 1119: Action = 3, Récompense = -1
# Étape 1120: Action = 3, Récompense = -1
# Étape 1121: Action = 0, Récompense = -1
# Étape 1122: Action = 3, Récompense = -1
# Étape 1123: Action = 3, Récompense = -1
# Étape 1124: Action = 2, Récompense = -1
# Étape 1125: Action = 5, Récompense = -10
# Étape 1126: Action = 3, Récompense = -1
# Étape 1127: Action = 4, Récompense = -1
# Étape 1128: Action = 3, Récompense = -1
# Étape 1129: Action = 4, Récompense = -10
# Étape 1130: Action = 3, Récompense = -1
# Étape 1131: Action = 3, Récompense = -1
# Étape 1132: Action = 5, Récompense = -1
# Étape 1133: Action = 2, Récompense = -1
# Étape 1134: Action = 2, Récompense = -1
# Étape 1135: Action = 0, Récompense = -1
# Étape 1136: Action = 4, Récompense = -10
# Étape 1137: Action = 0, Récompense = -1
# Étape 1138: Action = 1, Récompense = -1
# Étape 1139: Action = 1, Récompense = -1
# Étape 1140: Action = 3, Récompense = -1
# Étape 1141: Action = 5, Récompense = -10
# Étape 1142: Action = 4, Récompense = -10
# Étape 1143: Action = 2, Récompense = -1
# Étape 1144: Action = 1, Récompense = -1
# Étape 1145: Action = 1, Récompense = -1
# Étape 1146: Action = 5, Récompense = -10
# Étape 1147: Action = 1, Récompense = -1
# Étape 1148: Action = 5, Récompense = -10
# Étape 1149: Action = 3, Récompense = -1
# Étape 1150: Action = 4, Récompense = -10
# Étape 1151: Action = 3, Récompense = -1
# Étape 1152: Action = 3, Récompense = -1
# Étape 1153: Action = 1, Récompense = -1
# Étape 1154: Action = 4, Récompense = -10
# Étape 1155: Action = 2, Récompense = -1
# Étape 1156: Action = 0, Récompense = -1
# Étape 1157: Action = 5, Récompense = -10
# Étape 1158: Action = 4, Récompense = -10
# Étape 1159: Action = 2, Récompense = -1
# Étape 1160: Action = 3, Récompense = -1
# Étape 1161: Action = 5, Récompense = -10
# Étape 1162: Action = 5, Récompense = -10
# Étape 1163: Action = 2, Récompense = -1
# Étape 1164: Action = 1, Récompense = -1
# Étape 1165: Action = 1, Récompense = -1
# Étape 1166: Action = 3, Récompense = -1
# Étape 1167: Action = 0, Récompense = -1
# Étape 1168: Action = 5, Récompense = -10
# Étape 1169: Action = 3, Récompense = -1
# Étape 1170: Action = 0, Récompense = -1
# Étape 1171: Action = 5, Récompense = -10
# Étape 1172: Action = 1, Récompense = -1
# Étape 1173: Action = 3, Récompense = -1
# Étape 1174: Action = 5, Récompense = -10
# Étape 1175: Action = 1, Récompense = -1
# Étape 1176: Action = 2, Récompense = -1
# Étape 1177: Action = 5, Récompense = -10
# Étape 1178: Action = 4, Récompense = -10
# Étape 1179: Action = 3, Récompense = -1
# Étape 1180: Action = 2, Récompense = -1
# Étape 1181: Action = 5, Récompense = -10
# Étape 1182: Action = 1, Récompense = -1
# Étape 1183: Action = 1, Récompense = -1
# Étape 1184: Action = 1, Récompense = -1
# Étape 1185: Action = 2, Récompense = -1
# Étape 1186: Action = 4, Récompense = -10
# Étape 1187: Action = 5, Récompense = -10
# Étape 1188: Action = 5, Récompense = -10
# Étape 1189: Action = 0, Récompense = -1
# Étape 1190: Action = 4, Récompense = -10
# Étape 1191: Action = 2, Récompense = -1
# Étape 1192: Action = 2, Récompense = -1
# Étape 1193: Action = 5, Récompense = -10
# Étape 1194: Action = 0, Récompense = -1
# Étape 1195: Action = 3, Récompense = -1
# Étape 1196: Action = 1, Récompense = -1
# Étape 1197: Action = 3, Récompense = -1
# Étape 1198: Action = 1, Récompense = -1
# Étape 1199: Action = 1, Récompense = -1
# Étape 1200: Action = 3, Récompense = -1
# Étape 1201: Action = 4, Récompense = -10
# Étape 1202: Action = 4, Récompense = -10
# Étape 1203: Action = 3, Récompense = -1
# Étape 1204: Action = 4, Récompense = -10
# Étape 1205: Action = 5, Récompense = -10
# Étape 1206: Action = 2, Récompense = -1
# Étape 1207: Action = 2, Récompense = -1
# Étape 1208: Action = 0, Récompense = -1
# Étape 1209: Action = 2, Récompense = -1
# Étape 1210: Action = 4, Récompense = -10
# Étape 1211: Action = 1, Récompense = -1
# Étape 1212: Action = 2, Récompense = -1
# Étape 1213: Action = 3, Récompense = -1
# Étape 1214: Action = 2, Récompense = -1
# Étape 1215: Action = 1, Récompense = -1
# Étape 1216: Action = 5, Récompense = -10
# ...
# Étape 1206: Action = 4, Récompense = -10
# Étape 1207: Action = 2, Récompense = -1
# Étape 1208: Action = 0, Récompense = -1
# Étape 1209: Action = 1, Récompense = -1
# Étape 1210: Action = 0, Récompense = -1
# Étape 1211: Action = 2, Récompense = -1
# Étape 1212: Action = 3, Récompense = -1
# Étape 1213: Action = 4, Récompense = -10
# Étape 1214: Action = 2, Récompense = -1
# Étape 1215: Action = 3, Récompense = -1
# Étape 1216: Action = 2, Récompense = -1
# Étape 1217: Action = 0, Récompense = -1
# Étape 1218: Action = 1, Récompense = -1
# Étape 1219: Action = 4, Récompense = -10
# Étape 1220: Action = 2, Récompense = -1
# Étape 1221: Action = 2, Récompense = -1
# Étape 1222: Action = 1, Récompense = -1
# Étape 1223: Action = 5, Récompense = -10
# Étape 1224: Action = 5, Récompense = -10
# Étape 1225: Action = 4, Récompense = -10
# Étape 1226: Action = 0, Récompense = -1
# Étape 1227: Action = 4, Récompense = -10
# Étape 1228: Action = 2, Récompense = -1
# Étape 1229: Action = 3, Récompense = -1
# Étape 1230: Action = 0, Récompense = -1
# Étape 1231: Action = 0, Récompense = -1
# Étape 1232: Action = 4, Récompense = -10
# Étape 1233: Action = 1, Récompense = -1
# Étape 1234: Action = 0, Récompense = -1
# Étape 1235: Action = 0, Récompense = -1
# Étape 1236: Action = 4, Récompense = -10
# Étape 1237: Action = 1, Récompense = -1
# Étape 1238: Action = 3, Récompense = -1
# Étape 1239: Action = 4, Récompense = -10
# Étape 1240: Action = 0, Récompense = -1
# Étape 1241: Action = 0, Récompense = -1
# Étape 1242: Action = 0, Récompense = -1
# Étape 1243: Action = 2, Récompense = -1
# Étape 1244: Action = 0, Récompense = -1
# Étape 1245: Action = 1, Récompense = -1
# Étape 1246: Action = 3, Récompense = -1
# Étape 1247: Action = 1, Récompense = -1
# Étape 1248: Action = 0, Récompense = -1
# Étape 1249: Action = 1, Récompense = -1
# Étape 1250: Action = 5, Récompense = -10
# Étape 1251: Action = 4, Récompense = -10
# Étape 1252: Action = 1, Récompense = -1
# Étape 1253: Action = 1, Récompense = -1
# Étape 1254: Action = 1, Récompense = -1
# Étape 1255: Action = 5, Récompense = -10
# Étape 1256: Action = 1, Récompense = -1
# Étape 1257: Action = 1, Récompense = -1
# Étape 1258: Action = 4, Récompense = -10
# Étape 1259: Action = 0, Récompense = -1
# Étape 1260: Action = 2, Récompense = -1
# Étape 1261: Action = 4, Récompense = -10
# Étape 1262: Action = 3, Récompense = -1
# Étape 1263: Action = 3, Récompense = -1
# Étape 1264: Action = 3, Récompense = -1
# Étape 1265: Action = 1, Récompense = -1
# Étape 1266: Action = 4, Récompense = -10
# Étape 1267: Action = 1, Récompense = -1
# Étape 1268: Action = 5, Récompense = -10
# Étape 1269: Action = 0, Récompense = -1
# Étape 1270: Action = 4, Récompense = -10
# Étape 1271: Action = 1, Récompense = -1
# Étape 1272: Action = 4, Récompense = -10
# Étape 1273: Action = 4, Récompense = -10
# Étape 1274: Action = 0, Récompense = -1
# Étape 1275: Action = 2, Récompense = -1
# Étape 1276: Action = 2, Récompense = -1
# Étape 1277: Action = 5, Récompense = -10
# Étape 1278: Action = 2, Récompense = -1
# Étape 1279: Action = 3, Récompense = -1
# Étape 1280: Action = 0, Récompense = -1
# Étape 1281: Action = 5, Récompense = -10
# Étape 1282: Action = 5, Récompense = -10
# Étape 1283: Action = 5, Récompense = -10
# Étape 1284: Action = 3, Récompense = -1
# Étape 1285: Action = 1, Récompense = -1
# Étape 1286: Action = 5, Récompense = -10
# Étape 1287: Action = 4, Récompense = -10
# Étape 1288: Action = 4, Récompense = -10
# Étape 1289: Action = 3, Récompense = -1
# Étape 1290: Action = 4, Récompense = -10
# Étape 1291: Action = 0, Récompense = -1
# Étape 1292: Action = 4, Récompense = -10
# Étape 1293: Action = 0, Récompense = -1
# Étape 1294: Action = 2, Récompense = -1
# Étape 1295: Action = 2, Récompense = -1
# Étape 1296: Action = 4, Récompense = -10
# Étape 1297: Action = 3, Récompense = -1
# Étape 1298: Action = 2, Récompense = -1
# Étape 1299: Action = 3, Récompense = -1
# Étape 1300: Action = 4, Récompense = -10
# Étape 1301: Action = 2, Récompense = -1
# Étape 1302: Action = 4, Récompense = -10
# Étape 1303: Action = 4, Récompense = -10
# Étape 1304: Action = 5, Récompense = -10
# Étape 1305: Action = 3, Récompense = -1
# Étape 1306: Action = 2, Récompense = -1
# Étape 1307: Action = 0, Récompense = -1
# Étape 1308: Action = 2, Récompense = -1
# Étape 1309: Action = 0, Récompense = -1
# Étape 1310: Action = 4, Récompense = -10
# Étape 1311: Action = 4, Récompense = -10
# Étape 1312: Action = 3, Récompense = -1
# Étape 1313: Action = 2, Récompense = -1
# Étape 1314: Action = 2, Récompense = -1
# Étape 1315: Action = 5, Récompense = -10
# Étape 1316: Action = 2, Récompense = -1
# Étape 1317: Action = 1, Récompense = -1
# Étape 1318: Action = 3, Récompense = -1
# Étape 1319: Action = 5, Récompense = -10
# Étape 1320: Action = 2, Récompense = -1
# Étape 1321: Action = 5, Récompense = -10
# Étape 1322: Action = 0, Récompense = -1
# Étape 1323: Action = 3, Récompense = -1
# Étape 1324: Action = 4, Récompense = -10
# Étape 1325: Action = 2, Récompense = -1
# Étape 1326: Action = 4, Récompense = -10
# Étape 1327: Action = 5, Récompense = -10
# Étape 1328: Action = 2, Récompense = -1
# Étape 1329: Action = 5, Récompense = -10
# Étape 1330: Action = 2, Récompense = -1
# Étape 1331: Action = 2, Récompense = -1
# Étape 1332: Action = 0, Récompense = -1
# Étape 1333: Action = 3, Récompense = -1
# Étape 1334: Action = 2, Récompense = -1
# Étape 1335: Action = 0, Récompense = -1
# Étape 1336: Action = 0, Récompense = -1
# Étape 1337: Action = 3, Récompense = -1
# Étape 1338: Action = 4, Récompense = -10
# Étape 1339: Action = 2, Récompense = -1
# Étape 1340: Action = 5, Récompense = -10
# Étape 1341: Action = 4, Récompense = -10
# Étape 1342: Action = 1, Récompense = -1
# Étape 1343: Action = 4, Récompense = -10
# Étape 1344: Action = 3, Récompense = -1
# Étape 1345: Action = 3, Récompense = -1
# Étape 1346: Action = 3, Récompense = -1
# Étape 1347: Action = 3, Récompense = -1
# Étape 1348: Action = 4, Récompense = -10
# Étape 1349: Action = 2, Récompense = -1
# Étape 1350: Action = 2, Récompense = -1
# Étape 1351: Action = 3, Récompense = -1
# Étape 1352: Action = 5, Récompense = -10
# Étape 1353: Action = 5, Récompense = -10
# Étape 1354: Action = 2, Récompense = -1
# Étape 1355: Action = 0, Récompense = -1
# Étape 1356: Action = 0, Récompense = -1
# Étape 1357: Action = 0, Récompense = -1
# Étape 1358: Action = 3, Récompense = -1
# Étape 1359: Action = 2, Récompense = -1
# Étape 1360: Action = 4, Récompense = -10
# Étape 1361: Action = 5, Récompense = -10
# Étape 1362: Action = 0, Récompense = -1
# Étape 1363: Action = 5, Récompense = -10
# Étape 1364: Action = 4, Récompense = -10
# Étape 1365: Action = 4, Récompense = -10
# Étape 1366: Action = 0, Récompense = -1
# Étape 1367: Action = 5, Récompense = -10
# Étape 1368: Action = 0, Récompense = -1
# Étape 1369: Action = 1, Récompense = -1
# Étape 1370: Action = 2, Récompense = -1
# Étape 1371: Action = 1, Récompense = -1
# Étape 1372: Action = 1, Récompense = -1
# Étape 1373: Action = 3, Récompense = -1
# Étape 1374: Action = 3, Récompense = -1
# Étape 1375: Action = 4, Récompense = -10
# Étape 1376: Action = 2, Récompense = -1
# Étape 1377: Action = 5, Récompense = -10
# Étape 1378: Action = 1, Récompense = -1
# Étape 1379: Action = 3, Récompense = -1
# Étape 1380: Action = 0, Récompense = -1
# Étape 1381: Action = 4, Récompense = -10
# Étape 1382: Action = 5, Récompense = -10
# Étape 1383: Action = 0, Récompense = -1
# Étape 1384: Action = 4, Récompense = -10
# Étape 1385: Action = 3, Récompense = -1
# Étape 1386: Action = 1, Récompense = -1
# Étape 1387: Action = 0, Récompense = -1
# Étape 1388: Action = 5, Récompense = -10
# Étape 1389: Action = 2, Récompense = -1
# Étape 1390: Action = 5, Récompense = -10
# Étape 1391: Action = 5, Récompense = -10
# Étape 1392: Action = 1, Récompense = -1
# Étape 1393: Action = 5, Récompense = -10
# Étape 1394: Action = 2, Récompense = -1
# Étape 1395: Action = 3, Récompense = -1
# Étape 1396: Action = 5, Récompense = -10
# Étape 1397: Action = 3, Récompense = -1
# Étape 1398: Action = 1, Récompense = -1
# Étape 1399: Action = 3, Récompense = -1
# Étape 1400: Action = 0, Récompense = -1
# Étape 1401: Action = 2, Récompense = -1
# Étape 1402: Action = 3, Récompense = -1
# Étape 1403: Action = 0, Récompense = -1
# Étape 1404: Action = 0, Récompense = -1
# Étape 1405: Action = 0, Récompense = -1
# Étape 1406: Action = 3, Récompense = -1
# Étape 1407: Action = 2, Récompense = -1
# Étape 1408: Action = 2, Récompense = -1
# Étape 1409: Action = 1, Récompense = -1
# Étape 1410: Action = 0, Récompense = -1
# Étape 1411: Action = 0, Récompense = -1
# Étape 1412: Action = 1, Récompense = -1
# Étape 1413: Action = 4, Récompense = -10
# Étape 1414: Action = 3, Récompense = -1
# Étape 1415: Action = 4, Récompense = -10
# Étape 1416: Action = 0, Récompense = -1
# Étape 1417: Action = 1, Récompense = -1
# Étape 1418: Action = 2, Récompense = -1
# Étape 1419: Action = 5, Récompense = -10
# Étape 1420: Action = 4, Récompense = -10
# Étape 1421: Action = 2, Récompense = -1
# Étape 1422: Action = 1, Récompense = -1
# Étape 1423: Action = 2, Récompense = -1
# Étape 1424: Action = 1, Récompense = -1
# Étape 1425: Action = 3, Récompense = -1
# Étape 1426: Action = 1, Récompense = -1
# Étape 1427: Action = 4, Récompense = -10
# Étape 1428: Action = 0, Récompense = -1
# Étape 1429: Action = 1, Récompense = -1
# Étape 1430: Action = 1, Récompense = -1
# Étape 1431: Action = 5, Récompense = -10
# Étape 1432: Action = 2, Récompense = -1
# Étape 1433: Action = 5, Récompense = -10
# Étape 1434: Action = 2, Récompense = -1
# Étape 1435: Action = 4, Récompense = -10
# Étape 1436: Action = 5, Récompense = -10
# Étape 1437: Action = 0, Récompense = -1
# Étape 1438: Action = 5, Récompense = -10
# Étape 1439: Action = 2, Récompense = -1
# Étape 1440: Action = 5, Récompense = -10
# Étape 1441: Action = 2, Récompense = -1
# Étape 1442: Action = 4, Récompense = -10
# Étape 1443: Action = 1, Récompense = -1
# Étape 1444: Action = 3, Récompense = -1
# Étape 1445: Action = 3, Récompense = -1
# Étape 1446: Action = 0, Récompense = -1
# Étape 1447: Action = 3, Récompense = -1
# Étape 1448: Action = 5, Récompense = -10
# Étape 1449: Action = 5, Récompense = -10
# Étape 1450: Action = 1, Récompense = -1
# Étape 1451: Action = 3, Récompense = -1
# Étape 1452: Action = 4, Récompense = -10
# Étape 1453: Action = 3, Récompense = -1
# Étape 1454: Action = 2, Récompense = -1
# Étape 1455: Action = 1, Récompense = -1
# Étape 1456: Action = 4, Récompense = -10
# Étape 1457: Action = 3, Récompense = -1
# Étape 1458: Action = 4, Récompense = -10
# Étape 1459: Action = 0, Récompense = -1
# Étape 1460: Action = 4, Récompense = -10
# Étape 1461: Action = 2, Récompense = -1
# Étape 1462: Action = 0, Récompense = -1
# Étape 1463: Action = 1, Récompense = -1
# Étape 1464: Action = 5, Récompense = -10
# Étape 1465: Action = 2, Récompense = -1
# Étape 1466: Action = 3, Récompense = -1
# Étape 1467: Action = 4, Récompense = -10
# Étape 1468: Action = 1, Récompense = -1
# Étape 1469: Action = 3, Récompense = -1
# Étape 1470: Action = 1, Récompense = -1
# Étape 1471: Action = 0, Récompense = -1
# Étape 1472: Action = 5, Récompense = -10
# Étape 1473: Action = 3, Récompense = -1
# Étape 1474: Action = 1, Récompense = -1
# Étape 1475: Action = 2, Récompense = -1
# Étape 1476: Action = 0, Récompense = -1
# Étape 1477: Action = 0, Récompense = -1
# Étape 1478: Action = 3, Récompense = -1
# Étape 1479: Action = 4, Récompense = -10
# Étape 1480: Action = 2, Récompense = -1
# Étape 1481: Action = 2, Récompense = -1
# Étape 1482: Action = 5, Récompense = -10
# Étape 1483: Action = 0, Récompense = -1
# Étape 1484: Action = 1, Récompense = -1
# Étape 1485: Action = 2, Récompense = -1
# Étape 1486: Action = 2, Récompense = -1
# Étape 1487: Action = 3, Récompense = -1
# Étape 1488: Action = 3, Récompense = -1
# Étape 1489: Action = 0, Récompense = -1
# Étape 1490: Action = 0, Récompense = -1
# Étape 1491: Action = 2, Récompense = -1
# Étape 1492: Action = 3, Récompense = -1
# Étape 1493: Action = 5, Récompense = -10
# Étape 1494: Action = 4, Récompense = -10
# Étape 1495: Action = 2, Récompense = -1
# Étape 1496: Action = 4, Récompense = -10
# Étape 1497: Action = 5, Récompense = -10
# Étape 1498: Action = 1, Récompense = -1
# Étape 1499: Action = 1, Récompense = -1
# Étape 1500: Action = 3, Récompense = -1
# Étape 1501: Action = 3, Récompense = -1
# Étape 1502: Action = 1, Récompense = -1
# Étape 1503: Action = 0, Récompense = -1
# Étape 1504: Action = 1, Récompense = -1
# Étape 1505: Action = 0, Récompense = -1
# Étape 1506: Action = 2, Récompense = -1
# Étape 1507: Action = 3, Récompense = -1
# Étape 1508: Action = 2, Récompense = -1
# Étape 1509: Action = 2, Récompense = -1
# Étape 1510: Action = 0, Récompense = -1
# Étape 1511: Action = 2, Récompense = -1
# Étape 1512: Action = 3, Récompense = -1
# Étape 1513: Action = 1, Récompense = -1
# Étape 1514: Action = 3, Récompense = -1
# Étape 1515: Action = 0, Récompense = -1
# Étape 1516: Action = 1, Récompense = -1
# Étape 1517: Action = 2, Récompense = -1
# Étape 1518: Action = 1, Récompense = -1
# Étape 1519: Action = 1, Récompense = -1
# Étape 1520: Action = 3, Récompense = -1
# Étape 1521: Action = 2, Récompense = -1
# Étape 1522: Action = 3, Récompense = -1
# Étape 1523: Action = 2, Récompense = -1
# Étape 1524: Action = 3, Récompense = -1
# Étape 1525: Action = 0, Récompense = -1
# Étape 1526: Action = 1, Récompense = -1
# Étape 1527: Action = 5, Récompense = -10
# Étape 1528: Action = 4, Récompense = -1
# Étape 1529: Action = 2, Récompense = -1
# Étape 1530: Action = 5, Récompense = -10
# Étape 1531: Action = 4, Récompense = -10
# Étape 1532: Action = 2, Récompense = -1
# Étape 1533: Action = 4, Récompense = -10
# Étape 1534: Action = 5, Récompense = -10
# Étape 1535: Action = 1, Récompense = -1
# Étape 1536: Action = 1, Récompense = -1
# Étape 1537: Action = 4, Récompense = -10
# Étape 1538: Action = 0, Récompense = -1
# Étape 1539: Action = 4, Récompense = -10
# Étape 1540: Action = 5, Récompense = -10
# Étape 1541: Action = 1, Récompense = -1
# Étape 1542: Action = 5, Récompense = -10
# Étape 1543: Action = 4, Récompense = -10
# Étape 1544: Action = 4, Récompense = -10
# Étape 1545: Action = 4, Récompense = -10
# Étape 1546: Action = 3, Récompense = -1
# Étape 1547: Action = 0, Récompense = -1
# Étape 1548: Action = 4, Récompense = -10
# Étape 1549: Action = 3, Récompense = -1
# Étape 1550: Action = 5, Récompense = -10
# Étape 1551: Action = 2, Récompense = -1
# Étape 1552: Action = 5, Récompense = -10
# Étape 1553: Action = 5, Récompense = -10
# Étape 1554: Action = 3, Récompense = -1
# Étape 1555: Action = 5, Récompense = -10
# Étape 1556: Action = 2, Récompense = -1
# Étape 1557: Action = 5, Récompense = -10
# Étape 1558: Action = 4, Récompense = -10
# Étape 1559: Action = 5, Récompense = -10
# Étape 1560: Action = 0, Récompense = -1
# Étape 1561: Action = 5, Récompense = -10
# Étape 1562: Action = 4, Récompense = -10
# Étape 1563: Action = 4, Récompense = -10
# Étape 1564: Action = 2, Récompense = -1
# Étape 1565: Action = 2, Récompense = -1
# Étape 1566: Action = 4, Récompense = -10
# Étape 1567: Action = 2, Récompense = -1
# Étape 1568: Action = 5, Récompense = -10
# Étape 1569: Action = 5, Récompense = -10
# Étape 1570: Action = 5, Récompense = -10
# Étape 1571: Action = 3, Récompense = -1
# Étape 1572: Action = 5, Récompense = -10
# Étape 1573: Action = 0, Récompense = -1
# Étape 1574: Action = 0, Récompense = -1
# Étape 1575: Action = 2, Récompense = -1
# Étape 1576: Action = 2, Récompense = -1
# Étape 1577: Action = 1, Récompense = -1
# Étape 1578: Action = 2, Récompense = -1
# Étape 1579: Action = 3, Récompense = -1
# Étape 1580: Action = 0, Récompense = -1
# Étape 1581: Action = 2, Récompense = -1
# Étape 1582: Action = 5, Récompense = -10
# Étape 1583: Action = 2, Récompense = -1
# Étape 1584: Action = 2, Récompense = -1
# Étape 1585: Action = 3, Récompense = -1
# Étape 1586: Action = 2, Récompense = -1
# Étape 1587: Action = 3, Récompense = -1
# Étape 1588: Action = 3, Récompense = -1
# Étape 1589: Action = 3, Récompense = -1
# Étape 1590: Action = 0, Récompense = -1
# Étape 1591: Action = 1, Récompense = -1
# Étape 1592: Action = 5, Récompense = -10
# Étape 1593: Action = 2, Récompense = -1
# Étape 1594: Action = 0, Récompense = -1
# Étape 1595: Action = 1, Récompense = -1
# Étape 1596: Action = 3, Récompense = -1
# Étape 1597: Action = 4, Récompense = -10
# Étape 1598: Action = 4, Récompense = -10
# Étape 1599: Action = 0, Récompense = -1
# Étape 1600: Action = 0, Récompense = -1
# Étape 1601: Action = 5, Récompense = 20

# %% [markdown]
# <p style="color: yellow; font-size: 30px;">
#  Exercice 3 : Mise à jour PPO 🔄
# </p>

# %%
import gymnasium as gym
import numpy as np

env = gym.make("Taxi-v3")

gamma = 0.99
lr_policy = 0.1
lr_value = 0.1
clip_epsilon = 0.2
n_episodes = 20

state_size = env.observation_space.n
action_size = env.action_space.n

policy_table = np.ones((state_size, action_size)) / action_size
value_table = np.zeros(state_size)

def compute_discounted_rewards(rewards):
    discounted_rewards = []
    running_add = 0
    for r in reversed(rewards):
        running_add = r + gamma * running_add
        discounted_rewards.insert(0, running_add)
    return discounted_rewards

def update_policy_ppo(states, actions, advantages, old_probs):
    for state, action, advantage, old_prob in zip(states, actions, advantages, old_probs):
        current_prob = policy_table[state, action]
        ratio = current_prob / old_prob
        clipped_ratio = np.clip(ratio, 1 - clip_epsilon, 1 + clip_epsilon)
        policy_loss = -np.minimum(ratio * advantage, clipped_ratio * advantage)
        policy_table[state, action] -= lr_policy * policy_loss
        policy_table[state] = np.clip(policy_table[state], 1e-8, 1)
        policy_table[state] /= policy_table[state].sum()

for episode in range(n_episodes):
    state, _ = env.reset()
    done = False
    episode_states = []
    episode_actions = []
    episode_rewards = []
    episode_old_probs = []
    
    while not done:
        action_probs = policy_table[state]
        action = np.random.choice(action_size, p=action_probs)
        old_prob = action_probs[action]
        episode_old_probs.append(old_prob)
        next_state, reward, done, _, _ = env.step(action)
        episode_states.append(state)
        episode_actions.append(action)
        episode_rewards.append(reward)
        state = next_state
    
    discounted_rewards = compute_discounted_rewards(episode_rewards)
    
    advantages = []
    for state, reward in zip(episode_states, discounted_rewards):
        advantage = reward - value_table[state]
        advantages.append(advantage)
        value_table[state] += lr_value * advantage
    
    update_policy_ppo(episode_states, episode_actions, advantages, episode_old_probs)
    
    total_reward = sum(episode_rewards)
    print(f"Épisode {episode + 1}, Récompense totale: {total_reward}")

env.close()
# Out:
# Épisode 1, Récompense totale: -1974
# Épisode 2, Récompense totale: -2849
# Épisode 3, Récompense totale: -4008
# Épisode 4, Récompense totale: -4136

# %% [markdown]
# <p style="color: yellow; font-size: 30px;">
#  Exercice 4 : Évaluation de l’Agent 📊
# </p>

# %%
import gymnasium as gym
import numpy as np

env = gym.make("Taxi-v3")
num_eval_episodes = 20

def evaluate_agent(policy_table, num_episodes):
    total_rewards = []
    for ep in range(num_episodes):
        state, _ = env.reset()
        done = False
        total_reward = 0
        while not done:
            action = np.argmax(policy_table[state])
            next_state, reward, done, _, _ = env.step(action)
            total_reward += reward
            state = next_state
        total_rewards.append(total_reward)
    return total_rewards

random_policy = np.ones((env.observation_space.n, env.action_space.n)) / env.action_space.n
random_rewards = evaluate_agent(random_policy, num_eval_episodes)
print("Avant entraînement:")
print(f"Récompenses: {random_rewards}")
print(f"Moyenne: {np.mean(random_rewards):.2f}")
print(f"Écart-type: {np.std(random_rewards):.2f}\n")

trained_rewards = evaluate_agent(policy_table, num_eval_episodes)
print("Après entraînement:")
print(f"Récompenses: {trained_rewards}")
print(f"Moyenne: {np.mean(trained_rewards):.2f}")
print(f"Écart-type: {np.std(trained_rewards):.2f}")

env.close()
